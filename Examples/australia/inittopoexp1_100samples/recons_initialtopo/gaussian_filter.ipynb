# %%
from scipy import misc
import scipy as sp
import scipy.ndimage
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
import numpy as np

# %%
fig = plt.figure()
plt.gray()  # show the filtered result in grayscale
ax1 = fig.add_subplot(121)  # left side
ax2 = fig.add_subplot(122)  # right side
orig = misc.imread('smooth_10.png')
result = gaussian_filter(orig, sigma=5)
ax1.imshow(orig)
ax2.imshow(result)
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """

# %%
fig = plt.figure()
plt.gray()  # show the filtered result in grayscale
ax1 = fig.add_subplot(121)  # left side
ax2 = fig.add_subplot(122)  # right side
orig = misc.imread('smooth_10.png')
result = gaussian_filter(orig, sigma=(5,5,0))
ax1.imshow(orig)
ax2.imshow(result)
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """

# %%
fig = plt.figure()
plt.gray()  # show the filtered result in grayscale
ax1 = fig.add_subplot(121)  # left side
ax2 = fig.add_subplot(122)  # right side
orig = misc.imread('smooth_10.png')
result = gaussian_filter(orig, sigma=(15,15,0))
ax1.imshow(orig)
ax2.imshow(result)
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """

# %%
a = np.loadtxt('smooth_10.txt')
#weights = np.random.random((a.shape[0],a.shape[1]))

#weights = np.copy(a)
#weights = weights / np.sum(weights[:])


# b = sp.ndimage.filters.convolve(a, weights, mode='constant')
b = gaussian_filter(a, sigma=(2,2) )

# %%
plt.imshow(a, cmap='hot', interpolation='nearest')
plt.show()
plt.close()

# %%
plt.imshow(b, cmap='hot', interpolation='nearest')
plt.show()
plt.close()
